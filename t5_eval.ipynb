# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from peft import PeftModel
import pandas as pd
from bert_score import score
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
import nltk
nltk.download('punkt')
from sklearn.model_selection import train_test_split
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\yyxxc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def preprocess(tweet_series):
    stopwords = nltk.corpus.stopwords.words('english')
    other_exclusions = ["#ff", "ff", "rt"]
    stopwords.extend(other_exclusions)
    tweet_series = tweet_series.astype(str)

    tweet_series = tweet_series.str.replace(r'\s+', ' ', regex=True)
    tweet_series = tweet_series.str.replace(r'@[\w\-]+', '', regex=True)
    tweet_series = tweet_series.str.replace(r'http[s]?://\S+', '', regex=True)

    tweet_series = tweet_series.str.replace(r'[^a-zA-Z]', ' ', regex=True)
    tweet_series = tweet_series.str.replace(r'\s+', ' ', regex=True)
    tweet_series = tweet_series.str.replace(r'^\s+|\s+?$', '', regex=True)
    tweet_series = tweet_series.str.replace(r'\d+(\.\d+)?', 'numbr', regex=True)
    tweet_series = tweet_series.str.lower()

    tokenized = tweet_series.apply(lambda x: x.split())
    # tokenized = tokenized.apply(lambda x: [w for w in x if w not in stopwords])
    # tokenized = tokenized.apply(lambda x: [stemmer.stem(w) for w in x])
    cleaned = tokenized.apply(lambda x: ' '.join(x))
    return cleaned

# %%
model_path = "./lora-t5-base-hate-neutral"
tokenizer = AutoTokenizer.from_pretrained(model_path)
base_model = AutoModelForSeq2SeqLM.from_pretrained("google-t5/t5-base")
model = PeftModel.from_pretrained(base_model, model_path)
# Out:
# d:\anaconda3\envs\CS4248\Lib\site-packages\huggingface_hub\file_download.py:142: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\yyxxc\.cache\huggingface\hub\models--google-t5--t5-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
dataset = pd.read_csv("data.csv")
dataset["original_comment"] = preprocess(dataset["original_comment"])
dataset["non_offensive_comment"] = preprocess(dataset["non_offensive_comment"])
df_train, df = train_test_split(dataset, test_size=0.2, random_state=42)

texts = df["original_comment"].tolist()
refs = df["non_offensive_comment"].tolist()

texts_train = df_train["original_comment"].tolist()
refs_train = df_train["non_offensive_comment"].tolist()

# %%
print(len(texts), len(refs))
print(len(texts_train), len(refs_train))
# Out:
# 922 922
# 3688 3688

# %%
def generate_neutralized(texts, max_length=128):
    inputs = [f"neutralize: {t}" for t in texts]
    encodings = tokenizer(inputs, return_tensors="pt", padding=True, truncation=True).to(model.device)
    outputs = model.generate(**encodings, max_length=max_length)
    return tokenizer.batch_decode(outputs, skip_special_tokens=True)

preds = generate_neutralized(texts)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 7
#       4     outputs = model.generate(**encodings, max_length=max_length)
#       5     return tokenizer.batch_decode(outputs, skip_special_tokens=True)
# ----> 7 preds = generate_neutralized(texts)
#
# Cell In[24], line 4, in generate_neutralized(texts, max_length)
#       2 inputs = [f"neutralize: {t}" for t in texts]
#       3 encodings = tokenizer(inputs, return_tensors="pt", padding=True, truncation=True).to(model.device)
# ----> 4 outputs = model.generate(**encodings, max_length=max_length)
#       5 return tokenizer.batch_decode(outputs, skip_special_tokens=True)
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\peft\peft_model.py:2145, in PeftModelForSeq2SeqLM.generate(self, **kwargs)
#    2143     with self._enable_peft_forward_hooks(**kwargs):
#    2144         kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 2145         outputs = self.base_model.generate(**kwargs)
#    2146 else:
#    2147     if "input_ids" not in kwargs:
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\transformers\generation\utils.py:2141, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, **kwargs)
#    2137         raise ValueError("`attention_mask` passed to `generate` must be 2D.")
#    2139 if self.config.is_encoder_decoder and "encoder_outputs" not in model_kwargs:
#    2140     # if model is encoder decoder encoder_outputs are created and added to `model_kwargs`
# -> 2141     model_kwargs = self._prepare_encoder_decoder_kwargs_for_generation(
#    2142         inputs_tensor, model_kwargs, model_input_name, generation_config
#    2143     )
#    2145 # 5. Prepare `input_ids` which will be used for auto-regressive generation
#    2146 if self.config.is_encoder_decoder:
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\transformers\generation\utils.py:692, in GenerationMixin._prepare_encoder_decoder_kwargs_for_generation(self, inputs_tensor, model_kwargs, model_input_name, generation_config)
#     690 encoder_kwargs["return_dict"] = True
#     691 encoder_kwargs[model_input_name] = inputs_tensor
# --> 692 model_kwargs["encoder_outputs"]: ModelOutput = encoder(**encoder_kwargs)  # type: ignore
#     694 return model_kwargs
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\transformers\models\t5\modeling_t5.py:1131, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1114     layer_outputs = self._gradient_checkpointing_func(
#    1115         layer_module.forward,
#    1116         hidden_states,
#    (...)
#    1128         cache_position,
#    1129     )
#    1130 else:
# -> 1131     layer_outputs = layer_module(
#    1132         hidden_states,
#    1133         attention_mask=causal_mask,
#    1134         position_bias=position_bias,
#    1135         encoder_hidden_states=encoder_hidden_states,
#    1136         encoder_attention_mask=encoder_extended_attention_mask,
#    1137         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1138         layer_head_mask=layer_head_mask,
#    1139         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1140         past_key_value=past_key_values,
#    1141         use_cache=use_cache,
#    1142         output_attentions=output_attentions,
#    1143         return_dict=return_dict,
#    1144         cache_position=cache_position,
#    1145     )
#    1147 # layer_outputs is a tuple with:
#    1148 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1149 if use_cache is False:
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\transformers\models\t5\modeling_t5.py:732, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict, cache_position)
#     729     attention_outputs = attention_outputs + cross_attention_outputs[2:]
#     731 # Apply Feed Forward layer
# --> 732 hidden_states = self.layer[-1](hidden_states)
#     734 # clamp inf values to enable fp16 training
#     735 if hidden_states.dtype == torch.float16:
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\transformers\models\t5\modeling_t5.py:346, in T5LayerFF.forward(self, hidden_states)
#     344 def forward(self, hidden_states):
#     345     forwarded_states = self.layer_norm(hidden_states)
# --> 346     forwarded_states = self.DenseReluDense(forwarded_states)
#     347     hidden_states = hidden_states + self.dropout(forwarded_states)
#     348     return hidden_states
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\transformers\models\t5\modeling_t5.py:300, in T5DenseActDense.forward(self, hidden_states)
#     294 if (
#     295     isinstance(self.wo.weight, torch.Tensor)
#     296     and hidden_states.dtype != self.wo.weight.dtype
#     297     and self.wo.weight.dtype != torch.int8
#     298 ):
#     299     hidden_states = hidden_states.to(self.wo.weight.dtype)
# --> 300 hidden_states = self.wo(hidden_states)
#     301 return hidden_states
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\anaconda3\envs\CS4248\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
original_model = AutoModelForSeq2SeqLM.from_pretrained("google-t5/t5-small")
original_model.eval()
def generate_neutralized_original(texts, max_length=128):
    inputs = [f"neutralize: {t}" for t in texts]
    encodings = tokenizer(inputs, return_tensors="pt", padding=True, truncation=True).to(original_model.device)
    outputs = original_model.generate(**encodings, max_length=max_length)
    return tokenizer.batch_decode(outputs, skip_special_tokens=True)

preds_original = generate_neutralized_original(texts)

# %%
smoothie = SmoothingFunction().method4
bleu_scores = [
    sentence_bleu([ref.split()], pred.split(), smoothing_function=smoothie)
    for pred, ref in zip(preds, refs)
]
print("Avg BLEU:", sum(bleu_scores) / len(bleu_scores))
# Out:
# Avg BLEU: 0.3217395472608178

# %%
smoothie = SmoothingFunction().method4

bleu_scores_original = [
    sentence_bleu([ref.split()], pred_original.split(), smoothing_function=smoothie)
    for pred_original, ref in zip(preds_original, refs)
]

print("Pretrain BLEU:", sum(bleu_scores_original) / len(bleu_scores_original))
# Out:
# Pretrain BLEU: 0.2129090388525372

# %%
P, R, F1 = score(preds_original, refs, lang="en", verbose=True)
print("BERTScore F1 of Pretrained T5 model:", F1.mean().item())
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
# 100%|██████████| 29/29 [06:15<00:00, 12.94s/it]
# computing greedy matching.
#   0%|          | 0/15 [00:00<?, ?it/s]Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
#  13%|█▎        | 2/15 [00:00<00:00, 16.29it/s]Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
#  33%|███▎      | 5/15 [00:00<00:00, 22.81it/s]Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
#  67%|██████▋   | 10/15 [00:00<00:00, 31.63it/s]Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# 100%|██████████| 15/15 [00:00<00:00, 33.36it/s]
# done in 375.82 seconds, 2.45 sentences/sec
# BERTScore F1 of Pretrained T5 model: 0.8507360816001892

# %%
P, R, F1 = score(preds, refs, lang="en", verbose=True)
print("BERTScore F1:", F1.mean().item())
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
# 100%|██████████| 29/29 [03:15<00:00,  6.74s/it]
# computing greedy matching.
#  27%|██▋       | 4/15 [00:00<00:00, 36.99it/s]Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
# 100%|██████████| 15/15 [00:00<00:00, 54.81it/s]
# done in 195.81 seconds, 4.71 sentences/sec
# BERTScore F1: 0.9093093872070312

# %%
for i in range(len(preds)):
    print(f"Original: {texts[i]}")
    print(f"Reference: {refs[i]}")
    print(f"Generated: {preds[i]}")
    print("=============")
# Out:
# Original: rt this bitch feet been through years of slavery
# Reference: rt this person feet been through years of hardship
# Generated: rt this person feet been through years of slavery
# =============
# Original: son why is our mail lady so ghetto
# Reference: son why is our mail lady so unconventional
# Generated: son why is our mail lady so ghetto
# =============
# Original: the hoes finna be like owieee trey august and chris brown can have my baby at the same time lmfaooooooo hoes ain t loyal
# Reference: the individual finna be like owieee trey august and chris brown can have my baby at the same time lmfaooooooo individual ain t loyal
# Generated: the people finna be like owieee trey august and chris brown can have my baby at the same time lmfaooooooo people ain t loyal
# =============
# Original: rt you gotta be a really weak bitch to let somebody s tweets offend you especially if you never met the person
# Reference: rt you gotta be a really vulnerable person to let somebody s tweets offend you especially if you never met the person
# Generated: rt you gotta be a really weak person to let somebody s tweets offend you especially if you never met the person
# =============
# Original: you thought i was playin when i cut that bitch off
# Reference: you thought i was playin when i end that relationship with person off
# Generated: you thought i was playin when i cut that person off
# =============
# Original: rt not a flagrant lebrons a bitch
# Reference: rt not a flagrant lebrons a person
# Generated: rt not a flagrant lebrons a person
# =============
# Original: i need a bad bitch thats gon treat me good
# Reference: i need a bad person thats gon treat me good
# Generated: i need a bad person thats gon treat me good
# =============
# Original: these hoes gotta pay for my company
# Reference: these individual gotta pay for my company
# Generated: these people gotta pay for my company
# =============
# Original: rt it ain t nothin to cut that bitch off
# Reference: rt it ain t nothin to end that relationship with person off
# Generated: rt it ain t nothin to cut that person off
# =============
# Original: rt that s why you re so good at this game cause u sit on your unemployed nigger ass playing all day
# Reference: rt that s why you re so good at this game cause u sit on your unemployed nigger person playing all day
# Generated: rt that s why you re so good at this game cause u sit on your unemployed person person playing all day
# Original: man i m wish big booty bytches would use some other nickname other than judy shy is so typical and old
# Reference: man i m wish big booty bytches would use some other nickname other than judy shy is so typical and old
# Generated: man i m wish big booty bytches would use some other nickname other than judy shy is so typical and old
# =============
# Original: get a real hair cut faggot i served my country in the marines for years what have u done
# Reference: get a real hair cut faggot i served my country in the marines for years what have u done
# Generated: get a real hair cut person i served my country in the marines for years what have u done
# =============
# Original: but i live in the south lot more here my pop lives in rhode island hardly no niggers there
# Reference: but i live in the south lot more here my pop lives in rhode island hardly no niggers there
# Generated: but i live in the south lot more here my pop lives in rhode island hardly no niggers there
# =============
# Original: so if a girl gets drunk and does some hoe shit it s rape now
# Reference: so if a girl gets drunk and does some individual stuff it s rape now
# Generated: so if a girl gets drunk and does some people it s rape now
# =============
# Original: yall both gimped up ain t tht a bitch huh lol
# Reference: yall both gimped up ain t tht a person huh lol
# Generated: yall both gimped up ain t tht a person huh lol
# =============
# Original: rt bet y all bitches was deaf to mc lyte s words about being treated like a queen huh
# Reference: rt bet y all person was deaf to mc lyte s words about being treated like a queen huh
# Generated: rt bet y all person was deaf to mc lyte s words about being treated like a queen huh
# =============
# Original: you are a bitch
# Reference: you are a person
# Generated: you are a person
# =============
# Original: dope in the bag pretty bitch on the side i sell dope in the back if you tryna get high ty
# Reference: dope in the bag pretty person on the side i sell dope in the back if you tryna get high ty
# Generated: dope in the bag pretty person on the side i sell dope in the back if you tryna get high ty
# =============
# Original: ugly bitches always trynna take pics from the same angle guess it s they best side
# Reference: ugly person always trynna take pics from the same angle guess it s they best side
# Generated: ugly person always trynna take pics from the same angle guess it s they best side
# =============
# Original: that bitch is lyinggggg
# Reference: that person is lyinggggg
# Generated: that person is lyinggggg
# =============
# Original: nah bama fans ain t finna have a nigger running the offense
# Reference: nah bama fans ain t finna have a nigger running the offense
# Generated: nah bama fans ain t finna have a person running the offense
# =============
# Original: on westside i m screamin fuck kd bitch
# Reference: on westside i m screamin messing kd person
# Generated: on westside i m screamin messing around kd person
# =============
# Original: rt i don t have an iphone so i have to manually ignore these hoes
# Reference: rt i don t have an iphone so i have to manually ignore these individual
# Generated: rt i don t have an iphone so i have to manually ignore these people
# =============
# Original: naaaa just the faggots so i guess you wouldn t be around very long would ya
# Reference: naaaa just the faggots so i guess you wouldn t be around very long would ya
# Generated: naaaa just the messing arounds so i guess you wouldn t be around very long would ya
# =============
# Original: bitch nicca talmbout a mf peat df y all ain t da lakers
# Reference: person nicca talmbout a mf peat df y all ain t da lakers
# Generated: person nicca talmbout a mf peat df y all ain t da lakers
# =============
# Original: go jerk off to lollis faggot
# Reference: go jerk off to lollis faggot
# Generated: go jerk off to lollis person
# =============
# Original: so you support illegals coming here and spreading disease among americans dream that bitch
# Reference: so you support illegals coming here and spreading disease among americans dream that person
# Generated: so you support illegals coming here and spreading disease among americans dream that person
# =============
# Original: rt i hate when people take a picture and be like don t mind the background nah bitch imma mind
# Reference: rt i hate when people take a picture and be like don t mind the background nah person imma mind
# Generated: rt i hate when people take a picture and be like don t mind the background nah person imma mind
# =============
